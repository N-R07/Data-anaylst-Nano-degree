# %% [markdown]
# # Real-world Data Wrangling

# %% [markdown]
# In this project, you will apply the skills you acquired in the course to gather and wrangle real-world data with two datasets of your choice.
#
# You will retrieve and extract the data, assess the data programmatically and visually, accross elements of data quality and structure, and implement a cleaning strategy for the data. You will then store the updated data into your selected database/data store, combine the data, and answer a research question with the datasets.
#
# Throughout the process, you are expected to:
#
# 1. Explain your decisions towards methods used for gathering, assessing, cleaning, storing, and answering the research question
# 2. Write code comments so your code is more readable

# %% [markdown]
# ## 1. Gather data
#
# In this section, you will extract data using two different data gathering methods and combine the data. Use at least two different types of data-gathering methods.

# %% [markdown]
# ### **1.1.** Problem Statement

# %% [markdown]
# In this project, we will investigate the correlation between various movie attributes, such as budget, genres, and cast/crew information, with indicators of movie success like revenue and ratings.

# %% [markdown]
# ### **1.2.** Gather at least two datasets using two different data gathering methods
#
# List of data gathering methods:
#
# - Download data manually
# - Programmatically downloading files
# - Gather data by accessing APIs
# - Gather and extract data from HTML files using BeautifulSoup
# - Extract data from a SQL database
#
# Each dataset must have at least two variables, and have greater than 500 data samples within each dataset.
#
# For each dataset, briefly describe why you picked the dataset and the gathering method (2-3 full sentences), including the names and significance of the variables in the dataset. Show your work (e.g., if using an API to download the data, please include a snippet of your code).
#
# Load the dataset programmtically into this notebook.

# %%
# Importing all the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import json

# %matplotlib inline

# %% [markdown]
# #### **Dataset 1** This is a movie dataset containg information about various attributes related to movies and movie success. This has 4803 rows and 20 columns and was downloaded manually from kaggle.
#
# Type:  CSV File
#
# Method: The data was gathered using the "Downloading files" method from kaggle.
#
# Dataset variables:
#
# *   *Variable 1 budget*
# *   *Variable 2 genres*
# *   *Variable 3 homepage*
# *   *Variable 4 id*
# *   *Variable 5 keywords*
# *   *Variable 6 original_language*
# *   *Variable 7 original_title*
# *   *Variable 8 overview*
# *   *Variable 9 popularity*
# *   *Variable 10 production_companies*
# *   *Variable 11 production_countries*
# *   *Variable 12 release_date*
# *   *Variable 13 revenue*
# *   *Variable 14 runtime*
# *   *Variable 15 spoken_languages*
# *   *Variable 16 status*
# *   *Variable 17 tagline*
# *   *Variable 18 title*
# *   *Variable 19 vote_average*
# *   *Variable 20 vote_count*

# %%
#FILL IN 1st data gathering and loading method
# data gathered via downloading csv manually from kaggle
df1 = pd.read_csv('tmdb_5000_movies.csv')

# %%
df1
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# #### Dataset 2 : This is also dataset related to movie. It has information about movie credits i.e., cast and crew information of movies. This dataset  has 4803 rows and 4 columns. I chose this dataset as it was related to my first dataset.
#
# Type: database
#
# Method: The data was gathered from a database using sqlite3 package
#
# Dataset variables:
#
# *   *Variable 1 movie_id*
# *   *Variable 2 title*
# *   *Variable 3 cast*
# *   *Variable 4 crew*
#
# Note: This database was created from csv file downloaded from kaggle as suggested by Udacity mentor and then dataset 2 was gathered from the database using sqlite3, file containing steps of database creation is also saved with name Database_creation_dataset2. This method was used as Udacity workspace was not allowing installation of modules required for other methods.

# %%
# Gathering the second dataset from a database using sqlite3 package

conn = sqlite3.connect('movie_database.db')
# Example SQL query to select all data from the table
query = "SELECT * FROM movie_credits"

# Execute query and read into DataFrame
df2 = pd.read_sql_query(query, conn)

# Display the DataFrame
df2
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %% [markdown]
# Raw data is already stored in the form of csv's for both datasets.

# %% [markdown]
# ## 2. Assess data
#
# Assess the data according to data quality and tidiness metrics using the report below.
#
# List **two** data quality issues and **two** tidiness issues. Assess each data issue visually **and** programmatically, then briefly describe the issue you find.  **Make sure you include justifications for the methods you use for the assessment.**

# %% [markdown]
# ### Quality Issue 1:  Missing values

# %%
#Inspecting the dataframe visually for missing Values
df1.head(20)
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
# Visual assessment of df2 for missing values
df2.head(20)
# Out:
#     movie_id                                        title  \
# 0      19995                                       Avatar
# 1        285     Pirates of the Caribbean: At World's End
# 2     206647                                      Spectre
# 3      49026                        The Dark Knight Rises
# 4      49529                                  John Carter
# 5        559                                 Spider-Man 3
# 6      38757                                      Tangled
# 7      99861                      Avengers: Age of Ultron
# 8        767       Harry Potter and the Half-Blood Prince
# 9     209112           Batman v Superman: Dawn of Justice
# 10      1452                             Superman Returns
# 11     10764                            Quantum of Solace
# 12        58   Pirates of the Caribbean: Dead Man's Chest
# 13     57201                              The Lone Ranger
# 14     49521                                 Man of Steel
# ...

# %% [markdown]
# After visually inspeacting first 20 rows of df1 and df2,  I can see that there are some null values or missing values in df1. However, no null values were found in df2.

# %%
# Inspecting the dataframe programmatically
# Calculating missing values of df1 and df2
missing_values_df1 = df1.isnull().sum() 
print("Missing Values  - Dataset 1:\n", missing_values_df1)

missing_values_df2 = df2.isnull().sum() 
print("Missing Values  - Dataset 2:\n", missing_values_df2)
# Out:
# Missing Values  - Dataset 1:
#  budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64
# Missing Values  - Dataset 2:
#  movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# Programically also it can be seen that there are null values or missing values present in several columns in dataset 1 while there are none in dataset 2.

# %% [markdown]
# Issue and justification: There are missing values present in several columns in df1 which can be seen above. For example, columns like 'homepage', 'overview', 'release_date', and 'tagline' have notable missing values. This is a quality issue as missing values can potentially affect the accuracy and reliability of analysis results. However, there are no missing values in df2.

# %% [markdown]
# ### Quality Issue 2: Datatype issue

# %%
# Inspecting the dataframe df1 visually for Inconsistent Data Types
df1.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Now, inspecting df2
df2.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# Now, we will inspect the dataframe df1 and df2 programmatically for Inconsistent Data Types

# %%
# Inspecting the dataframes df1 and df2 for data types
data_types = pd.concat([df1.dtypes, df2.dtypes], axis=1, keys=['df1', 'df2'])
data_types
# Out:
#                           df1     df2
# budget                  int64     NaN
# genres                 object     NaN
# homepage               object     NaN
# id                      int64     NaN
# keywords               object     NaN
# original_language      object     NaN
# original_title         object     NaN
# overview               object     NaN
# popularity            float64     NaN
# production_companies   object     NaN
# production_countries   object     NaN
# release_date           object     NaN
# revenue                 int64     NaN
# runtime               float64     NaN
# spoken_languages       object     NaN
# status                 object     NaN
# tagline                object     NaN
# title                  object  object
# vote_average          float64     NaN
# vote_count              int64     NaN
# movie_id                  NaN   int64
# cast                      NaN  object
# crew                      NaN  object

# %% [markdown]
# From assessing these dataframes visually and programmically for data types, we can see that release_date in df1 has object datatype instead of datetime type. Similarly columns like genres, keywords, production_companies, production_countries, and spoken_languages in df1 and cast and crew in df2 are stored as strings, which is not ideal for extraction and analysis.

# %% [markdown]
# Issue and justification: The data types of columns are inconsistent across the dataset. Inconsistent data types can lead to errors during analysis or modeling so ensuring uniform data types across relevant columns is crucial for maintaining consistency and accuracy in data processing and analysis tasks. Thus, this is a data quality issue.

# %% [markdown]
# ### Tidiness Issue 1: Multiple Variables Stored in One Column

# %%
# Inspecting the dataframe visually

dataframes = pd.concat([df1.head(), df2.head()], axis=1, keys=['df1', 'df2'])
dataframes
# Out:
#          df1                                                     \
#       budget                                             genres
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                          \
#                                        homepage      id
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                                                         \
# ...

# %% [markdown]
# From visual assessment we can see that columns in df1 such as genres, keywords, production_companies, production_countries, and spoken_languages contain multiple variables in a stringified JSON format or like list of dictionaries. Similarly, df2 has cast and crew columns with the same issue.

# %%
# Inspecting the dataframe programmatically  (Taking example of genres column in df1 only as others also have similar issue to show tidiness issue)

#  Extracting the value of the 'genres' column from the first row of DataFrame df1
genres = df1.loc[0, 'genres']

# Programmatically inspecting structure of 'genres'
print("'genres' column data:")
print(genres)

# Checking the type of the data stored in 'genres'
print("\nData type of 'genres':", type(genres))
# Out:
# 'genres' column data:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#
# Data type of 'genres': <class 'str'>

# %% [markdown]
# From programmatical inspection of genres column, we found that the genres column data is stored as a string (str type), even though it visually represents a list of dictionaries.

# %% [markdown]
# Issue and justification:  The presence of multiple variables (e.g., different genres) within a single column (genres) violates tidy data principles, specifically the rule that each variable should occupy its own column. This complicates analysis, as extracting information from these columns requires additional data processing steps. Parsing these stringified JSON columns into a more analyzable format will significantly improve the dataset's usability for analysis purposes.

# %% [markdown]
# ### Tidiness Issue 2:  Inconsistent Column Names Across DataFrames

# %%
# Inspecting the dataframes visually

# First few rows of both dataframes 
dataframes   # already defined above
# Out:
#          df1                                                     \
#       budget                                             genres
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                          \
#                                        homepage      id
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                                                         \
# ...

# %% [markdown]
# From visual inspection, the inconsistency is evident in the column names used to reference the movie's unique identifier: id in df1 and movie_id in df2.

# %%
#FILL IN - Inspecting the dataframe programmatically to highlight inconsistent column names

# Displaying the column names of both dataframes to compare
df1_columns = df1.columns.tolist()
df2_columns = df2.columns.tolist()

# Highlighting the inconsistency by printing column names
print("df1 Columns:", df1_columns)
print("\n df2 Columns:", df2_columns)

# Specifically highlighting the unique identifier columns
print("\nUnique Identifier in 'df1': 'id'")
print("Unique Identifier in 'df2': 'movie_id'")

# Checkng if the values in 'movie_id' column in credits_df are the same as the values in 'id' column in df2
same_values = (df2['movie_id'] == df1['id']).all()
print('\n', same_values)
# Out:
# df1 Columns: ['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language', 'original_title', 'overview', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']
#
#  df2 Columns: ['movie_id', 'title', 'cast', 'crew']
#
# Unique Identifier in 'df1': 'id'
# Unique Identifier in 'df2': 'movie_id'
#
#  True

# %% [markdown]
# The programmatic comparison makes it clear that while both columns serve the same purpose (as a unique identifier for movies), they are named differently in the two datasets. Also, they have the same values in all rows.

# %% [markdown]
# Issue and justification: This inconsistency in column names across related dataframes complicates data merging and manipulation. So, aligning column names before merging ensures clarity and efficiency in data handling, adhering to best practices for data tidiness and manipulation.

# %% [markdown]
# ## 3. Clean data
# Clean the data to solve the 4 issues corresponding to data quality and tidiness found in the assessing step. **Make sure you include justifications for your cleaning decisions.**
#
# After the cleaning for each issue, please use **either** the visually or programatical method to validate the cleaning was succesful.
#
# At this stage, you are also expected to remove variables that are unnecessary for your analysis and combine your datasets. Depending on your datasets, you may choose to perform variable combination and elimination before or after the cleaning stage. Your dataset must have **at least** 4 variables after combining the data.

# %%
# Making copies of the datasets to ensure the raw dataframes are not impacted
df1_movie = df1
df2_credit = df2

# %% [markdown]
# ### Quality Issue 1: Missing Values

# %% [markdown]
# The columns 'tagline' and 'homepage' have significant number of missing values and these are not crucial for our analysis also. Hence, removing these columns to clean df1.

# %%
# Removing 'tagline' and 'homepage' columns from df1_movie
df1_clean = df1_movie.drop(columns=['tagline', 'homepage'])

# %%
# Validate the cleaning was successful
# Listng columns names to show that the 'tagline' and 'homepage' columns have been removed.
columns_after_removal = df1_clean.columns.tolist()
columns_after_removal
# Out:
# ['budget',
#  'genres',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'title',
#  'vote_average',
#  'vote_count']

# %% [markdown]
# This shows that the 'tagline' and 'homepage' columns have been successfully removed from the dataset. The remaining columns now include essential variables for analysis, such as budget, genres, and revenue, among others.

# %% [markdown]
# Justification: The columns 'tagline' and 'homepage' have significant number of missing values and these are not crucial for our analysis also. Hence, we have removed these columns to clean our dataframe so that missing values in these columns won't affect our result. Also, the other two columns 'overview' and 'release_date' has only 3 and 1 missing value which doesn't impact our analysis much as this are very low values and by keeping those rows intact we can preserve other valuable data in those rows.

# %% [markdown]
# ### Quality Issue 2: Incorrect datatype

# %% [markdown]
# The 'release_date' column has to be converted to datetime.

# %%
#  Converting 'release_date' to datetime
df1_clean['release_date'] = pd.to_datetime(df1_clean['release_date'])

# %%
# Validating the cleaning was successful by checking data types
df1_clean['release_date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# This shows that the cleaning has been successful.

# %% [markdown]
# Justification: The 'release_date' column has to be converted to datetime so that date-related operations could be performed if required for doing time analysis.
#
# The columns in both the dataframes which are stored in the JSON string format will be cleaned in the tidiness issue.

# %% [markdown]
# ### **Tidiness Issue 1:  Multiple Variables Stored in One Column**

# %%
# Parsing the 'genres' column to a list of dictionaries
df1_clean['genres'] = df1_clean['genres'].apply(lambda x: json.loads(x.replace('\'', '"')) if isinstance(x, str) else [])

# Exploding the 'genres' list to create separate rows for each genre
df1_clean_exploded = df1_clean.explode('genres')

# Extracting genre names (as each dictionary in 'genres' list has a 'name' key)
df1_clean_exploded['genre'] = df1_clean_exploded['genres'].apply(lambda x: x.get('name') if isinstance(x, dict) else None)

# Dropping the original 'genres' column if no longer needed
df1_clean_exploded = df1_clean_exploded.drop(columns=['genres'])

# %%
#FILL IN - Validate the cleaning was successful
df1_clean_exploded.head()
# Out:
#       budget     id                                           keywords  \
# 0  237000000  19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 0  237000000  19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 0  237000000  19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 0  237000000  19995  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  300000000    285  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#   original_language                            original_title  \
# 0                en                                    Avatar
# 0                en                                    Avatar
# 0                en                                    Avatar
# 0                en                                    Avatar
# 1                en  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# ...

# %%
# Parsing the stringified JSON data in the 'cast' column
df2_credit['cast'] = df2_credit['cast'].apply(lambda x: json.loads(x) if isinstance(x, str) else [])

# Exploding the 'cast' list to create separate rows for each cast member
df2_clean_exploded_cast = df2_credit.explode('cast')

# Extracting the cast name from the list of dictionaries in the 'cast' column
df2_clean_exploded_cast['cast_name'] = df2_clean_exploded_cast['cast'].apply(lambda x: x.get('character') if isinstance(x, dict) else None)

# Dropping the original 'cast' column if no longer needed
df2_clean_exploded = df2_clean_exploded_cast.drop(columns=['cast'])

# %%
#Validating that cast column has also been exploded

df2_clean_exploded.head()
# Out:
#    movie_id   title                                               crew  \
# 0     19995  Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...
# 0     19995  Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...
# 0     19995  Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...
# 0     19995  Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...
# 0     19995  Avatar  [{"credit_id": "52fe48009251416c750aca23", "de...
#
#              cast_name
# 0           Jake Sully
# 0              Neytiri
# 0  Dr. Grace Augustine
# 0        Col. Quaritch
# 0         Trudy Chacon

# %% [markdown]
# Justification: According to tidy data principles, each variable must have its own column, and each observation must have its own row. By parsing and exploding the genres and cast column, we adhere to these principles. This will also allow us to examine how individual genres or cast member perform affect success metrics without the complexities of dealing with multi-genre movies or multiple cast members as a single observation. I have not parsed crew, keyword and other similar columns as they are not required for analysis and so I'll remove them before merging datasets.

# %% [markdown]
# ### **Tidiness Issue 2: Inconsistent Column Names Across DataFrames:**

# %% [markdown]
# We will standardize the column names by renaming movie_id in df2 to id to match df1 so that there won't be any issue when merging datasets.

# %%
# Renaming 'movie_id' column in 'df2' to 'id'
df2_clean_exploded = df2_clean_exploded.rename(columns={'movie_id': 'id'})

# %%
# Validate the cleaning by checking column names
df2_clean_exploded.columns.tolist()
# Out:
# ['id', 'title', 'crew', 'cast_name']

# %% [markdown]
# The movie_id column in df2_clean_exploded has been successfully renamed to id, aligning with the column name in df1_clean_exploded.

# %% [markdown]
# Justification: This standardization facilitates the merging of these datasets on the common identifier.

# %% [markdown]
# ### **Remove unnecessary variables and combine datasets**
#
# Depending on the datasets, you can also peform the combination before the cleaning steps.

# %%
#  Removing unnecessary variables from dataframe df1_clean_exploded and df2_clean_exploded 
df1_final = df1_clean_exploded.drop(columns=['keywords', 'original_language','original_title','overview','popularity','production_companies','production_countries','runtime','spoken_languages','status','vote_count'])
print ('First few rows of df1_final :')
print(df1_final.head())

df2_final = df2_clean_exploded.drop(columns=['crew','title'])
print ('\n First few rows of df2_final :')
print(df2_final.head())
# Out:
# First few rows of df1_final :
#       budget     id release_date     revenue  \
# 0  237000000  19995   2009-12-10  2787965087
# 0  237000000  19995   2009-12-10  2787965087
# 0  237000000  19995   2009-12-10  2787965087
# 0  237000000  19995   2009-12-10  2787965087
# 1  300000000    285   2007-05-19   961000000
#
#                                       title  vote_average            genre
# 0                                    Avatar           7.2           Action
# 0                                    Avatar           7.2        Adventure
# 0                                    Avatar           7.2          Fantasy
# 0                                    Avatar           7.2  Science Fiction
# 1  Pirates of the Caribbean: At World's End           6.9        Adventure
#
#  First few rows of df2_final :
#       id            cast_name
# 0  19995           Jake Sully
# 0  19995              Neytiri
# 0  19995  Dr. Grace Augustine
# 0  19995        Col. Quaritch
# ...

# %%
# Combining datasets
combined_df = pd.merge(df1_final, df2_final, on='id')

# %%
#Lets view first few rows of our combined dataset
combined_df.head()
# Out:
#       budget     id release_date     revenue   title  vote_average   genre  \
# 0  237000000  19995   2009-12-10  2787965087  Avatar           7.2  Action
# 1  237000000  19995   2009-12-10  2787965087  Avatar           7.2  Action
# 2  237000000  19995   2009-12-10  2787965087  Avatar           7.2  Action
# 3  237000000  19995   2009-12-10  2787965087  Avatar           7.2  Action
# 4  237000000  19995   2009-12-10  2787965087  Avatar           7.2  Action
#
#              cast_name
# 0           Jake Sully
# 1              Neytiri
# 2  Dr. Grace Augustine
# 3        Col. Quaritch
# 4         Trudy Chacon

# %% [markdown]
# ## 4. Update your data store

# %%
# Saving the cleaned combined dataset to a CSV file
cleaned_data_filename = 'cleaned_combined_movies_data.csv'
combined_df.to_csv(cleaned_data_filename, index=False)

# Outputting the filename to confirm saving
cleaned_data_filename
# Out:
# 'cleaned_combined_movies_data.csv'

# %% [markdown]
# ## 5. Answer the research question
#
# ### **5.1:** Define and answer the research question
# Going back to the problem statement in step 1, use the cleaned data to answer the question you raised. Produce **at least** two visualizations using the cleaned data and explain how they help you answer the question.

# %% [markdown]
# *Research question:* What is the correlation between various movie attributes, such as budget, genres, and cast/crew information, with indicators of movie success like revenue and ratings.

# %% [markdown]
# Defining function to avoid repetitive code

# %%
# Function to create scatter plots to explore correlations
def plot_correlation(df, x_var, y_var, title, xlabel, ylabel):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x=x_var, y=y_var)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %% [markdown]
# ####  Visual 1 -Correlation between Budget and Revenue

# %%
# Correlation between Budget and Revenue
plot_correlation(combined_df, 'budget', 'revenue', 'Correlation between Budget and Revenue', 'Budget', 'Revenue')

# %% [markdown]
# *Answer to research question:* The scatter plot showing the correlation between budget and revenue suggests that there is a positive relationship between these two variables. Movies with higher budgets tend to generate higher revenue, which can be attributed to larger budgets allowing for better production quality, more prominent actors, and more extensive marketing campaigns that attract larger audiences.

# %% [markdown]
# #### Visual 2 - Correlation between Budget and Ratings

# %%
# Correlation between Budget and Ratings
plot_correlation(combined_df, 'budget', 'vote_average', 'Correlation between Budget and Ratings', 'Budget', 'Ratings')

# %% [markdown]
# *Answer to research question:* The correlation between the budget of a movie and its ratings (vote_average) does not show a strong linear relationship as seen with revenue. While there are movies with high budgets and high ratings, there's a wide spread of ratings across different budget levels. This suggests that a larger budget does not necessarily guarantee higher ratings.

# %% [markdown]
# ### **5.2:** Reflection
# In 2-4 sentences, if you had more time to complete the project, what actions would you take? For example, which data quality and structural issues would you look into further, and what research questions would you further explore?

# %% [markdown]
# *Answer:*If I had more time to complete the project, I would delve deeper into analyzing cast and crew data to understand the impact of specific actors or directors on movie success and explore how release timing affects movie performance, considering factors like seasonality. Also, I would investigate the interaction between movie genres and other variables (e.g., budget, cast) to identify successful combinations. These steps would provide a better understanding of what other factors contribute to a movie's success.
